# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
salaries = pd.read_csv('./Salaries.csv',low_memory=False)
salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148049 non-null object
# OvertimePay         148654 non-null object
# OtherPay            148654 non-null object
# Benefits            112495 non-null object
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              38119 non-null object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
salaries = salaries.convert_objects(convert_numeric=True)
salaries.info()
# Out:
# E:\ProgramFiles\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# ...

# %%
#median for Base Pay
p1=round(salaries.groupby(['JobTitle'])['BasePay'].median(),3).nlargest(10)
p1
# Out:
# JobTitle
# Chief of Police                           307450.040
# Chief, Fire Department                    302068.000
# Gen Mgr, Public Trnsp Dept                294000.180
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)    285262.000
# Mayor                                     281537.170
# Dep Dir for Investments, Ret              276153.765
# Dept Head V                               270616.270
# Adm, SFGH Medical Center                  268946.020
# Controller                                267914.000
# EXECUTIVE CONTRACT EMPLOYEE               264452.520
# Name: BasePay, dtype: float64

# %%
p1.plot(kind='barh',title='排名前十岗位的基本工资中位数',color='lightblue')

# %%
p2=round(salaries.groupby(['JobTitle'])['BasePay'].median(),3).nsmallest(14)
p2
# Out:
# JobTitle
# ASSISTANT RECREATION SUPERVISOR              0.00
# Assistant Recreation Director                0.00
# Cashier 3                                    0.00
# Conversion                                   0.00
# PUBLIC SAFETY COMMUNICATIONS TECHNICIAN      0.00
# RECREATION DIRECTOR                          0.00
# Recreation Director                          0.00
# WAREHOUSE WORKER                             0.00
# BOARD/COMMISSION MEMBER, GROUP II          200.00
# BdComm Mbr, Grp2,M=$25/Mtg                 250.00
# SPECIAL EXAMINER                           492.96
# Special Examiner                           598.50
# Special Assistant 14                       619.88
# BOARD/COMMISSION MEMBER, GROUP III         630.00
# Name: BasePay, dtype: float64

# %%
p2[p2>0].plot(kind='barh',title='排名后十岗位的基本工资中位数',color='lightblue')

# %%
p3=round(salaries.groupby(['JobTitle'])['OvertimePay'].median(),4).nlargest(10)
p3
# Out:
# JobTitle
# Wire Rope Cable Maint Sprv                      81313.49
# WIRE ROPE CABLE MAINTENANCE SUPERVISOR          66164.73
# Trnst Power Line Wrk Sprv 2                     66006.10
# Battalion Chief, Fire Suppress                  48063.51
# SENIOR POWER GENERATION TECHNICIAN              46504.35
# ASSISTANT INSPECTOR (POLICE DEPARTMENT)         45679.84
# Incident Support Specialist                     45022.34
# MECHANICAL SHOP AND EQUIPMENT SUPERINTENDENT    44930.70
# Transit Power Line Sprv1                        44422.37
# Asst Chf of Dept (Fire Dept)                    43389.97
# Name: OvertimePay, dtype: float64

# %%
p3.plot(kind='barh',title='排名前十岗位的加班费中位数',color='lightblue')

# %%
p4=round(salaries.groupby(['JobTitle'])['OvertimePay'].median(),4).nsmallest(15)
p4
# Out:
# JobTitle
# ACCOUNT CLERK                                         0.0
# ACCOUNTANT                                            0.0
# ACCOUNTANT INTERN                                     0.0
# ACPO,JuvP, Juv Prob (SFERS)                           0.0
# ACUPUNCTURIST                                         0.0
# ADMINISTRATIVE ANALYST                                0.0
# ADMINISTRATIVE ANALYST II                             0.0
# ADMINISTRATIVE ANALYST III                            0.0
# ADMINISTRATIVE ENGINEER                               0.0
# ADMINISTRATIVE SERVICES MANAGER                       0.0
# ADMINISTRATOR, SFGH MEDICAL CENTER                    0.0
# AFFIRMATIVE ACTION SPECIALIST                         0.0
# AGRICULTURAL INSPECTOR                                0.0
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI    0.0
# AIRPORT ASSISTANT DEPUTY DIRECTOR, OPERATIONS         0.0
# Name: OvertimePay, dtype: float64

# %%
salaries.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency Status
# 148649    NaN  San Francisco     PT
# 148650    NaN  San Francisco    NaN
# ...

# %%
salaries.describe(include=['O'])
# Out:
#        EmployeeName          JobTitle         Agency Status
# count        148654            148654         148654  38119
# unique       110811              2159              1      2
# top       Kevin Lee  Transit Operator  San Francisco     FT
# freq             13              7036         148654  22334

# %%
salaries.corr()
# Out:
#                         Id   BasePay  OvertimePay  OtherPay  Benefits  \
# Id                1.000000 -0.204878    -0.081505 -0.100403 -0.348957
# BasePay          -0.204878  1.000000     0.266740  0.285655  0.918028
# OvertimePay      -0.081505  0.266740     1.000000  0.316592  0.301207
# OtherPay         -0.100403  0.285655     0.316592  1.000000  0.233178
# Benefits         -0.348957  0.918028     0.301207  0.233178  1.000000
# TotalPay         -0.211478  0.954494     0.504859  0.470496  0.884097
# TotalPayBenefits -0.092190  0.946595     0.467981  0.422341  0.930140
# Year              0.968171  0.033751     0.027887 -0.002499 -0.043136
# Notes                  NaN       NaN          NaN       NaN       NaN
#
#                   TotalPay  TotalPayBenefits      Year  Notes
# Id               -0.211478         -0.092190  0.968171    NaN
# BasePay           0.954494          0.946595  0.033751    NaN
# OvertimePay       0.504859          0.467981  0.027887    NaN
# ...

# %%
salaries= salaries.drop(["Id", "Notes", "Status", "Agency"], axis = 1)
salaries = salaries.dropna()
salaries
# Out:
#                   EmployeeName                        JobTitle    BasePay  \
# 36159           Gary Altenberg    Lieutenant, Fire Suppression  128808.87
# 36160             Gregory Suhr                 Chief of Police  302578.00
# 36161               Khoa Trinh     Electronic Maintenance Tech  111921.00
# 36162       Joanne Hayes-White          Chief, Fire Department  296943.01
# 36163        Frederick Binkley       EMT/Paramedic/Firefighter  126863.19
# 36164                 Amy Hart                     Dept Head V  271607.74
# 36165           Edward Reiskin      Gen Mgr, Public Trnsp Dept  294000.17
# 36166              John Martin                     Dept Head V  287747.89
# 36167            John Goldberg                       Captain 3  104404.00
# 36168           David Franklin    Asst Chf of Dept (Fire Dept)  204032.52
# 36169             Brendan Ward  Battlion Chief, Fire Suppressi  174822.47
# 36170               Samson Lai  Battlion Chief, Fire Suppressi  174822.44
# ...

# %%
salaries['JobTitle'].value_counts()[0:10]
# Out:
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Custodian                       2409
# Firefighter                     2348
# Recreation Leader               1968
# Patient Care Assistant          1940
# Deputy Sheriff                  1914
# Name: JobTitle, dtype: int64

# %%
job_transit=salaries[salaries.JobTitle.str.contains('transit operator')]
job_transit.median()
# Out:
# EmployeeName       NaN
# JobTitle           NaN
# BasePay            NaN
# OvertimePay        NaN
# OtherPay           NaN
# Benefits           NaN
# TotalPay           NaN
# TotalPayBenefits   NaN
# Year               NaN
# dtype: float64

# %%
job_nurse=salaries[salaries.JobTitle.str.contains('special nurse')]
job_nurse.median()
# Out:
# EmployeeName       NaN
# JobTitle           NaN
# BasePay            NaN
# OvertimePay        NaN
# OtherPay           NaN
# Benefits           NaN
# TotalPay           NaN
# TotalPayBenefits   NaN
# Year               NaN
# dtype: float64

# %%
salaries[salaries.JobTitle.str.contains('chief of police')]
# Out:
# Empty DataFrame
# Columns: [EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year]
# Index: []

# %%
#Top 15 sectors for SF salary analysis

plt.figure('Bar',figsize=(7,7))
sectors = salaries['JobTitle'].value_counts()[0:10]
plt.barh(sectors.index,sectors,0.4,color='lightblue',label='sectors')
plt.xlabel('岗位人数', fontsize=14)
plt.ylabel("岗位名称", fontsize=14)
plt.title("就业人数排名前十的岗位")
plt.ylim((0, 8))
plt.legend()
plt.show()

# %%
salaries.head()
# Out:
#              EmployeeName                      JobTitle    BasePay  \
# 36159      Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160        Gregory Suhr               Chief of Police  302578.00
# 36161          Khoa Trinh   Electronic Maintenance Tech  111921.00
# 36162  Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163   Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 36159    220909.48  13126.31  44430.12  362844.66         407274.78  2012
# 36160         0.00  18974.11  69810.19  321552.11         391362.30  2012
# 36161    146415.32  78057.41  53102.29  336393.73         389496.02  2012
# 36162         0.00  17816.59  72047.88  314759.60         386807.48  2012
# 36163    192424.49  17917.18  44438.25  337204.86         381643.11  2012

# %%
salaries.JobTitle = salaries.JobTitle.str.lower()
#if job title has more than 500 data points as True False
criteria = salaries.JobTitle.value_counts()>500
#take job title more than 500 data points
jobtitlelist = salaries.JobTitle.value_counts()[criteria].reset_index()
#
df = salaries[['JobTitle', 'TotalPayBenefits']]
#
df = df[df.JobTitle.isin(jobtitlelist['index'])]
#
pivoted_data = df.pivot_table('TotalPayBenefits', index='JobTitle' , aggfunc=np.mean)
#
sorted_salaries = pivoted_data.sort_values(by='TotalPayBenefits', ascending= False)
print(sorted_salaries[:10])
# Out:
#                               TotalPayBenefits
# JobTitle
# lieutenant, fire suppression     224969.190262
# sergeant 3                       203342.311367
# firefighter                      183920.449549
# attorney (civil/criminal)        179887.048897
# police officer 2                 171833.605439
# emt/paramedic/firefighter        168571.910055
# police officer 3                 168324.707520
# registered nurse                 152088.359925
# assoc engineer                   144881.200158
# deputy sheriff                   144193.930408

# %%
sorted_salaries[0:10].plot.bar(title='收入排名前十的岗位')

# %%
# Let’s find the employees who earn the highest totalPay amount in each year.
salaries.JobTitle = salaries.JobTitle.str.lower()
years = salaries.Year.unique()
print(years)
for year in years:
    sorteddata = salaries[salaries.Year==year].sort_values(by='TotalPay',ascending=False)
    person = sorteddata.EmployeeName.iloc[0]
    salary = sorteddata.TotalPay.iloc[0]
    print("在 %d年 %s 赚钱最多的员工是 %8.1f"%(year,person,salary))
# Out:
# [2012 2013 2014]
# 在 2012年 Gary Altenberg 赚钱最多的员工是 362844.7
# 在 2013年 Samson  Lai 赚钱最多的员工是 347102.3
# 在 2014年 David Shinn 赚钱最多的员工是 471952.6

# %%
#Finding the number of unique job titles and print 10 most frequent job titles.
print("唯一的岗位数量是 %d"%len(np.unique(salaries.JobTitle)))
print("岗位名称            出现频率")
print(salaries.JobTitle.value_counts()[0:10])
# Out:
# 唯一的岗位数量是 1109
# 岗位名称            出现频率
# transit operator                6975
# special nurse                   4382
# registered nurse                3725
# public svc aide-public works    2514
# police officer 3                2411
# custodian                       2409
# firefighter                     2348
# recreation leader               1968
# patient care assistant          1940
# deputy sheriff                  1914
# Name: JobTitle, dtype: int64

# %%
salaries.JobTitle.value_counts()[0:10].plot.bar()

# %%
# Calculating the average TotalPay values for each of the the 10 most frequent
jobtitlelist = salaries.JobTitle.value_counts()[0:10]
data_10jobtitle = salaries[salaries.JobTitle.isin(jobtitlelist.index)]
avgsalary_10jobtitle=data_10jobtitle.groupby(by=data_10jobtitle.JobTitle).TotalPay.mean()
print(avgsalary_10jobtitle)
# Out:
# JobTitle
# custodian                        47232.360216
# deputy sheriff                  110746.221708
# firefighter                     146531.255741
# patient care assistant           47230.551835
# police officer 3                135365.411248
# public svc aide-public works      8253.873946
# recreation leader                 6675.061021
# registered nurse                116036.368054
# special nurse                    33213.889131
# transit operator                 65261.941287
# Name: TotalPay, dtype: float64

# %%
avgsalary_10jobtitle.plot.bar()

# %%
df1=salaries.pivot_table(index=['EmployeeName','JobTitle'], columns=['Year'],values=['TotalPay'])

df1
# Out:
#                                                                TotalPay  \
# Year                                                               2012
# EmployeeName                  JobTitle
# A Bernard  Fatooh             sheriff's property keeper             NaN
# A Bernard Fatooh              sheriff's property keeper        18500.19
# A K Finizio                   customer service agent trainee        NaN
# A. James  Robertson Ii        superior court judge                  NaN
# A. James Robertson Ii         superior court judge             22065.71
# A.K.  Finizio                 customer service agent trainee        NaN
# Aaliyah Hogue                 public svc aide-public works      2493.61
# Aaliyah Javae'Mercedes O'Neal publ svc aide-asst to prof            NaN
# Aaliyah V Hogue               junior clerk                          NaN
# Aaran Luo                     transit operator                 78118.96
# ...

# %%
df1.query('EmployeeName==["David Shinn"]')
# Out:
#                              TotalPay
# Year                             2012 2013       2014
# EmployeeName JobTitle
# David Shinn  deputy chief 3  275747.3  NaN  471952.64

# %%
df2=salaries.groupby(by=['JobTitle','Year']).agg({'JobTitle':len})
df2
# Out:
#                                      JobTitle
# JobTitle                       Year
# account clerk                  2012        85
#                                2013        87
#                                2014        93
# accountant i                   2012         3
#                                2013         3
#                                2014         2
# accountant ii                  2012        72
#                                2013        77
#                                2014        77
# accountant iii                 2012        88
#                                2013        89
#                                2014        99
# accountant intern              2012        26
#                                2013        23
#                                2014        11
# accountant iv                  2012        54
#                                2013        55
#                                2014        62
# acpo,juvp, juv prob (sfers)    2014         1
# ...

# %%
filter =salaries.groupby('JobTitle').filter(lambda x: len(x) < 3)
filter
# Out:
#                   EmployeeName                        JobTitle    BasePay  \
# 36216              Robert Shaw    dep dir for investments, ret  236735.52
# 36340            Nikolas Lemos           forensic toxicologist  187207.03
# 36483            Terrence Yuen         court executive officer  185054.80
# 36997              Allen Nance     asst chf prob ofc, juv prob  167361.04
# 37325                   Ron Ho       director, info tech group  163349.00
# 37570          Leonard Broberg             assistant inspector  128367.81
# 38503         Timothy Hatfield   airport mechanical maint sprv  125626.98
# 38641            Michael Haase  asst chf, bur clm invest&admin  137874.49
# 38916            Michelle Long        asst dir clinical svcs 2  135171.64
# 39067             Martha Blake                   crime lab mgr  136963.00
# 39092              Marc Slavin            special assistant 16  132254.27
# 39338                 Sue Wong       director, fiscal services  132582.01
# ...

# %%
ret_loss=filter.drop_duplicates("JobTitle")
ret_loss
# Out:
#                   EmployeeName                        JobTitle    BasePay  \
# 36216              Robert Shaw    dep dir for investments, ret  236735.52
# 36340            Nikolas Lemos           forensic toxicologist  187207.03
# 36483            Terrence Yuen         court executive officer  185054.80
# 36997              Allen Nance     asst chf prob ofc, juv prob  167361.04
# 37325                   Ron Ho       director, info tech group  163349.00
# 37570          Leonard Broberg             assistant inspector  128367.81
# 38503         Timothy Hatfield   airport mechanical maint sprv  125626.98
# 38641            Michael Haase  asst chf, bur clm invest&admin  137874.49
# 38916            Michelle Long        asst dir clinical svcs 2  135171.64
# 39067             Martha Blake                   crime lab mgr  136963.00
# 39092              Marc Slavin            special assistant 16  132254.27
# 39338                 Sue Wong       director, fiscal services  132582.01
# ...

# %%
ret_loss.to_excel('loss.xls')

# %%
df3=salaries.pivot_table(index=['Year'], values=['TotalPayBenefits'] ,aggfunc=[np.sum,np.mean,len],margins=True)
df3
# Out:
#                   sum             mean              len
#      TotalPayBenefits TotalPayBenefits TotalPayBenefits
# Year
# 2012     3.696940e+09    100553.229232          36766.0
# 2013     3.808882e+09    102939.981346          37001.0
# 2014     3.821866e+09    100261.438668          38119.0
# All      1.132769e+10    101243.122968         111886.0

# %%
increse_pay_2013=1-(df3.iat[0,1]/df3.iat[1,1])
increse_pay_2014=1-(df3.iat[1,1]/df3.iat[2,1])
increse_pay_2013,increse_pay_2014
# Out:
# (0.023185861144766506, -0.026715581916383346)
